# %% [markdown]
# # Web scraping Disney movies collection data

# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import re

# %%
#load the page
r = requests.get("https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films")

#convert to bs object
soup = bs(r.content)

# %%
#find all headings with size 3 to get the years in string
soup.find_all("h3")
# Out:
# [<h3><span id="1930s.E2.80.931940s"></span><span class="mw-headline" id="1930s–1940s">1930s–1940s</span></h3>,
#  <h3><span class="mw-headline" id="1950s">1950s</span></h3>,
#  <h3><span class="mw-headline" id="1960s">1960s</span></h3>,
#  <h3><span class="mw-headline" id="1970s">1970s</span></h3>,
#  <h3><span class="mw-headline" id="1980s">1980s</span></h3>,
#  <h3><span class="mw-headline" id="1990s">1990s</span></h3>,
#  <h3><span class="mw-headline" id="2000s">2000s</span></h3>,
#  <h3><span class="mw-headline" id="2010s">2010s</span></h3>,
#  <h3><span class="mw-headline" id="2020s">2020s</span></h3>,
#  <h3><span class="mw-headline" id="Undated_films">Undated films</span></h3>,
#  <h3 class="vector-menu-heading" id="p-personal-label">
#  <span class="vector-menu-heading-label">Personal tools</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-namespaces-label">
#  <span class="vector-menu-heading-label">Namespaces</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-views-label">
#  <span class="vector-menu-heading-label">Views</span>
#  </h3>,
#  <h3>
#  <label for="searchInput">Search</label>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-navigation-label">
#  <span class="vector-menu-heading-label">Navigation</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-interaction-label">
#  <span class="vector-menu-heading-label">Contribute</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-tb-label">
#  <span class="vector-menu-heading-label">Tools</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-coll-print_export-label">
#  <span class="vector-menu-heading-label">Print/export</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
#  <span class="vector-menu-heading-label">In other projects</span>
#  </h3>,
#  <h3 class="vector-menu-heading" id="p-lang-label">
#  <span class="vector-menu-heading-label">Languages</span>
#  </h3>]

# %% [markdown]
# We will get a value of None in the first header3 because we have two span elements inside this first header. So we need to manually replace the first value of the list above with the respective year, i.e., 1930s-1940s.

# %%
#collecting the number of years first
#create an emtpy list of years
years_list = []
for years in soup.find_all("h3"):
    
    if years.string is not None:
        years = years.string.replace('s','')
        years_list.append(years)
    
    print(years)
# Out:
# <h3><span id="1930s.E2.80.931940s"></span><span class="mw-headline" id="1930s–1940s">1930s–1940s</span></h3>
# 1950
# 1960
# 1970
# 1980
# 1990
# 2000
# 2010
# 2020
# Undated film
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span class="vector-menu-heading-label">Personal tools</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span class="vector-menu-heading-label">Namespaces</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-views-label">
# <span class="vector-menu-heading-label">Views</span>
# </h3>
# <h3>
# <label for="searchInput">Search</label>
# </h3>
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span class="vector-menu-heading-label">Navigation</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span class="vector-menu-heading-label">Contribute</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span class="vector-menu-heading-label">In other projects</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span class="vector-menu-heading-label">Languages</span>
# </h3>

# %%
#printing the list
years_list
# Out:
# ['1950',
#  '1960',
#  '1970',
#  '1980',
#  '1990',
#  '2000',
#  '2010',
#  '2020',
#  'Undated film']

# %%
#insert the years 1930s-1940s as a first index value
years_list.insert(0,'1930-1940')
years_list.insert(9,'Upcoming')

# %%
#printing the years list
years_list
# Out:
# ['1930-1940',
#  '1950',
#  '1960',
#  '1970',
#  '1980',
#  '1990',
#  '2000',
#  '2010',
#  '2020',
#  'Upcoming',
#  'Undated film']

# %%
for tag in soup.find_all("href"):
    print(tag)

# %% [markdown]
# Now upon inspecting the table we want to extract, we have links for each of the movie title and that will provide us with more information about each movie. We need to loop through each of these movie title and get the link and access the page for that movie.

# %%
#create empty list of links to movie title
data = {} 

init = 0
#loop through the table tags
for table in soup.find_all("table"):
    movies =[]
    #loop through each table to get all the links
    for link in table.find_all("i"):
        
        #try and except to ignore the errors in title extraction
        try:
            #get the link of movie title
            title_page = 'https://en.wikipedia.org' + link.a['href']
            #add it to the list of movies
            movies.append(title_page)
        except:
            pass
     
    
    try:
        data[years_list[init]] = movies
        init = init +1
    except:
        pass

# %%
#we can check the data for upcoming films 
data['Upcoming']
# Out:
# ['https://en.wikipedia.org/wiki/Pinocchio_(2022_live-action_film)',
#  'https://en.wikipedia.org/wiki/Hocus_Pocus_2',
#  'https://en.wikipedia.org/wiki/Strange_World_(film)',
#  'https://en.wikipedia.org/wiki/Disenchanted_(film)',
#  'https://en.wikipedia.org/wiki/Haunted_Mansion_(2023_film)',
#  'https://en.wikipedia.org/wiki/The_Little_Mermaid_(2023_film)',
#  'https://en.wikipedia.org/wiki/Elemental_(2023_film)']

# %% [markdown]
# ## Using Pandas library to get the table

# %%
#taking Turning red movie page for an example
page = requests.get("https://en.m.wikipedia.org/wiki/Turning_Red")

# %%
#reading the content of the page directly using pandas read_html and putting it to a dataframe
df_movie= pd.read_html(page.content)[0]

# %%
df_movie.set_index(df_movie.columns[0]).transpose()
# Out:
# Turning Red    Official promotional poster Directed by        Screenplay by  \
# Turning Red.1  Official promotional poster   Domee Shi  Julia Cho Domee Shi
#
# Turning Red                               Story by      Produced by  \
# Turning Red.1  Domee Shi Julia Cho Sarah Streicher  Lindsey Collins
#
# Turning Red                                             Starring  \
# Turning Red.1  Rosalie Chiang Sandra Oh Ava Morse Hyein Park ...
#
# Turning Red                      Cinematography  \
# Turning Red.1  Mahyar Abousaeedi Jonathan Pytko
#
# Turning Red                        Edited by          Music by  \
# Turning Red.1  Nicholas C. Smith Steve Bloom  Ludwig Göransson
#
# Turning Red                             Productioncompanies  \
# Turning Red.1  Walt Disney Pictures Pixar Animation Studios
#
# Turning Red                        Distributed by  \
# Turning Red.1  Walt Disney StudiosMotion Pictures
#
# Turning Red                                      Release dates  \
# Turning Red.1  March 1, 2022El Capitan Theatre) March 11, 2022
#
# Turning Red      Running time        Country Language           Budget  \
# Turning Red.1  100 minutes[1]  United States  English  $175 million[2]
#
# Turning Red          Box office
# Turning Red.1  $19.9 million[3]

# %% [markdown]
# The problem here is that we cannot get the names separated with commas or any such information that needs to be punctuated for that matter.

# %% [markdown]
# ## Using Beautiful Soup to extract tables

# %%
"""
   This function will find the column name based on the movie details by matching it with the dictionary of columns created below. 
   This will check for a matching word in the list of all columns ce
   
   Inputs: Word --> A word from the movie details like "Directed by"
   
"""
def key_finder(word, keys_list):
    final_word = ""
    init_num = 0 
    for prop in keys_list:
        count =0

        for letter in word:
            if letter in prop:
                count +=1

        if count > init_num:
            init_num = count 
            final_word = prop

    return final_word

# %%
#find the first table of the movie page

def movie_details_collector(page_content):
    table = page_content.find("table")
    
    #set the key to initially to an empty value
    key = '' 
    
    dict_movie_props = {'Title':'','Based on':'','Directed by':'','Written by':'','Screenplay by':'','Story by':'','Produced by':'','Starring':'',\
                     'Cinematography':'','Edited by':'','Music by':'', 'Productioncompanies':'',\
                     'Distributed by':'','Narrated by':'','Created by':'','Genre':'', 'Color process':'',\
                     'Release dates':'','Running time':'','Country':'','Language':'','Budget':'','Box office':''}
    
    keys_list = [cols for cols in dict_movie_props.keys()]
    #initialize 
    num = 1
    init = 0

    #iterate through the table to find th and td tagsf
    for items in table.find_all(["th","td"]): 

        #get the name of the movie
        if init == 0:
            dict_movie_props['Title'] = items.get_text()
            init += 1
            #print(items.get_text(), num)
        else:

            #if the item is odd we get the th tag's text as keys of a dictionary
            if num % 2 != 0:
                #print(items.get_text(), num)
                key = key_finder(items.get_text()[:10], keys_list)
                if key in keys_list:
                    key = key
                else:
                    key = ''

            #else for even value of num we get the td tag values
            else:
                #print(items.get_text(), num)
                value = items.get_text().replace("\n",",")
                #if value[0] == ',':
                #    value = value[1:] 
                if num !=2:
                    dict_movie_props[key] = value
                else:
                    pass
                #print("key = "+ key)

        #print(dict_movie_props)
        num += 1

    return dict_movie_props

# %%
"""
 A function to add numpy null values where the information is provided for a property of a movie
"""
def add_null_values(dict_of_props):
    for det in dict_of_props.items():
        if det[1] == '':
            dict_of_props[det[0]] = np.NaN

    return dict_of_props

# %%
def create_list_of_values(dict_movie_prop): 
    values_list = []
    for values in dict_movie_prop.values():
        values_list.append(values)
    
    return values_list

# %% [markdown]
# Now we will put everything together and call the appropriate functions to loop through each page of movies collected earlier.
#
# ## Collecting Details Finally
#
#
# Note: Nikki: Wild Dog of the North needs to be removed due to technical issues as cited on its wikipedia page. Tall Tale from 1995 also needs to be removed for issues with the page.

# %%
# %%capture
#Create a loop that can go through each of the movie page and collect the relevant data

#create empty dictionary with the keys having different properties of a movie
dataframe_columns = ['Title','Based on','Directed by','Written by','Screenplay by','Story by','Produced by','Starring',\
                         'Cinematography','Edited by','Music by', 'Productioncompanies',\
                         'Distributed by','Narrated by','Created by','Genre','Color process',\
                         'Release dates','Running time','Country','Language','Budget','Box office']

#collecting columns names
keys_list = dataframe_columns

#create a dataframe with just the columns
df= pd.DataFrame(columns = dataframe_columns)

#loop through each of the movies link available in dictionary of data
#for link in data.values():
for items in data['2000']:
    page = requests.get(items)
    page_content = bs(page.content)

    #to check if the movie page is having any issues


    if "Please help improve this article by adding citations to reliable sources." in page_content.table.get_text():
        pass
    else:
        dict_movie_details = movie_details_collector(page_content)

        #get the null values added for empty values
        dict_movie_details = add_null_values(dict_movie_details)


        df = df.append(pd.DataFrame([create_list_of_values(dict_movie_details)], 
             columns=dataframe_columns), 
             ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:982, in _finalize_columns_and_data(content, columns, dtype)
#     981 try:
# --> 982     columns = _validate_or_indexify_columns(contents, columns)
#     983 except AssertionError as err:
#     984     # GH#26429 do not raise user-facing AssertionError
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:1030, in _validate_or_indexify_columns(content, columns)
#    1028 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1029     # caller's responsibility to check for this...
# -> 1030     raise AssertionError(
#    1031         f"{len(columns)} columns passed, passed data had "
#    1032         f"{len(content)} columns"
#    1033     )
#    1034 elif is_mi_list:
#    1035
#    1036     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 23 columns passed, passed data had 24 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [1000], in <cell line: 17>()
#      29 #get the null values added for empty values
#      30 dict_movie_details = add_null_values(dict_movie_details)
# ---> 33 df = df.append(pd.DataFrame([create_list_of_values(dict_movie_details)],
#      34      columns=dataframe_columns),
#      35      ignore_index=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:721, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     716     if columns is not None:
#     717         # error: Argument 1 to "ensure_index" has incompatible type
#     718         # "Collection[Any]"; expected "Union[Union[Union[ExtensionArray,
#     719         # ndarray], Index, Series], Sequence[Any]]"
#     720         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 721     arrays, columns, index = nested_data_to_arrays(
#     722         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     723         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     724         data,
#     725         columns,
#     726         index,  # type: ignore[arg-type]
#     727         dtype,
#     728     )
#     729     mgr = arrays_to_mgr(
#     730         arrays,
#     731         columns,
#    (...)
#     734         typ=manager,
#     735     )
#     736 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:519, in nested_data_to_arrays(data, columns, index, dtype)
#     516 if is_named_tuple(data[0]) and columns is None:
#     517     columns = ensure_index(data[0]._fields)
# --> 519 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     520 columns = ensure_index(columns)
#     522 if index is None:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:883, in to_arrays(data, columns, dtype)
#     880     data = [tuple(x) for x in data]
#     881     arr = _list_to_arrays(data)
# --> 883 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     884 return content, columns
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:985, in _finalize_columns_and_data(content, columns, dtype)
#     982     columns = _validate_or_indexify_columns(contents, columns)
#     983 except AssertionError as err:
#     984     # GH#26429 do not raise user-facing AssertionError
# --> 985     raise ValueError(err) from err
#     987 if len(contents) and contents[0].dtype == np.object_:
#     988     contents = _convert_object_array(contents, dtype=dtype)
#
# ValueError: 23 columns passed, passed data had 24 columns

# %%
df
# Out:
#                                        Title  \
# 0                           The Tigger Movie
# 1               Whispers: An Elephant's Tale
# 2                                   Dinosaur
# 3                              Fantasia 2000
# 4                                    The Kid
# 5   The Little Mermaid II: Return to the Sea
# 6                        Remember the Titans
# 7                             102 Dalmatians
# 8                   The Emperor's New Groove
# 9                       Recess: School's Out
# 10  Lady and the Tramp II: Scamp's Adventure
# 11                 Atlantis: The Lost Empire
# 12                      The Princess Diaries
# 13                     Max Keeble's Big Move
# 14                            Monsters, Inc.
# 15                                       NaN
# 16                      Return to Never Land
# 17            Cinderella II:Dreams Come True
# 18                                       NaN
#
#                                         Based on  \
# 0               Characters createdby A. A. Milne
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5   The Little Mermaidby Hans Christian Andersen
# 6                                            NaN
# 7   The Hundred and One Dalmatiansby Dodie Smith
# 8    Original storyby Roger AllersMatthew Jacobs
# 9          Recessby Paul GermainJoe Ansolabehere
# 10                                           NaN
# 11                                    ,Atlantis,
# 12              The Princess Diariesby Meg Cabot
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16              Characters createdby J.M. Barrie
# 17                                           NaN
# 18                                           NaN
#
#                                           Directed by  \
# 0                                     Jun Falkenstein
# 1                                      Dereck Joubert
# 2                        ,Ralph Zondag,Eric Leighton,
# 3   ,Don Hahn,Pixote Hunt,Hendel Butoy,Eric Goldbe...
# 4                                      Jon Turteltaub
# 5                                        Jim Kammerud
# 6                                          Boaz Yakin
# 7                                          Kevin Lima
# 8                                         Mark Dindal
# 9                                        Chuck Sheetz
# 10                  ,Darrell Rooney,Jeannine Roussel,
# 11                         ,Gary Trousdale,Kirk Wise,
# 12                                     Garry Marshall
# 13                                           Tim Hill
# 14                                        Pete Docter
# 15                                                NaN
# 16                                         Robin Budd
# 17                                         John Kafka
# 18                                                NaN
#
#                                            Written by  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                        Audrey Wells
# 5   ,Elizabeth Anderson,Temple Mathews,Elise D'Hae...
# 6                                Gregory Allen Howard
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17             Jill E. BlotevogelTom RogersJule Selbo
# 18                                                NaN
#
#                                         Screenplay by  \
# 0                                     Jun Falkenstein
# 1   ,Dereck Joubert,Jordan Moffet,Holly Goldberg S...
# 2                ,John Harrison,Robert Nelson Jacobs,
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   ,Kristen Buckley,Brian Regan,Bob Tzudiker,Noni...
# 8                                      David Reynolds
# 9                                  Jonathan Greenberg
# 10                               ,Bill Motz,Bob Roth,
# 11                                         Tab Murphy
# 12                                       Gina Wendkos
# 13        Jonathan BernsteinMark BlackwellJames Greer
# 14                        Andrew StantonDaniel Gerson
# 15                                                NaN
# 16                                     Temple Mathews
# 17                                                NaN
# 18                                                NaN
#
#                                              Story by  \
# 0                                      Eddie Guzelian
# 1                    ,Dereck Joubert,Beverly Joubert,
# 2   ,John Harrison,Robert Nelson Jacobs,Thom Enriq...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                       ,Kristen Buckley,Brian Regan,
# 8                        ,Chris Williams,Mark Dindal,
# 9   ,Paul Germain,Joe Ansolabehere,Jonathan Greenb...
# 10                                                NaN
# 11  ,Kirk Wise,Gary Trousdale,Joss Whedon,Bryce Za...
# 12                                                NaN
# 13  David WattsJonathan BernsteinMark BlackwellJam...
# 14  Pete DocterJill CultonJeff PidgeonRalph Eggleston
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#                                           Produced by  \
# 0                                        Cheryl Abood
# 1                    ,Beverly Joubert,Dereck Joubert,
# 2                                         Pam Marsden
# 3                     ,Roy E. Disney,Donald W. Ernst,
# 4     ,Hunt Lowry,Christina Steinberg,Jon Turteltaub,
# 5                       ,Leslie Hough,David Lovegren,
# 6                          Jerry BruckheimerChad Oman
# 7                                   Edward S. Feldman
# 8                                       Randy Fullmer
# 9   ,Joe Ansolabehere,Paul Germain,Toshio Suzuki (...
# 10      ,Jeannine Roussel,David W. King,Cory Edwards,
# 11                                           Don Hahn
# 12  ,Whitney Houston,Debra Martin Chase,Mario Isco...
# 13                                          Mike Karz
# 14                                  Darla K. Anderson
# 15                                                NaN
# 16  ,Christopher Chase,Michelle Pappalardo-Robinso...
# 17                        Mary ThorneMary Alice Drumm
# 18                                                NaN
#
#                                              Starring  \
# 0   ,Jim Cummings,Nikita Hopkins,Ken Sansom,John F...
# 1   ,Angela Bassett,Joanna Lumley,Anne Archer,Debi...
# 2   ,D. B. Sweeney,Alfre Woodard,Ossie Davis,Max C...
# 3   ,James Levine,Steve Martin,Itzhak Perlman,Quin...
# 4   ,Bruce Willis,Spencer Breslin,Emily Mortimer,L...
# 5   ,Jodi Benson,Tara Charendoff,Samuel E. Wright,...
# 6   ,Denzel Washington,Will Patton,Donald Faison,N...
# 7   ,Glenn Close,Ioan Gruffudd,Alice Evans,Tim McI...
# 8   ,David Spade,John Goodman,Eartha Kitt,Patrick ...
# 9   ,Andrew Lawrence,Rickey D'Shon Collins,Jason D...
# 10  ,Scott Wolf,Alyssa Milano,Chazz Palminteri,Jef...
# 11  ,Michael J. Fox,James Garner,Cree Summer,Don N...
# 12  ,Anne Hathaway,Héctor Elizondo,Heather Mataraz...
# 13  Alex D. LinzLarry MillerJamie KennedyNora Dunn...
# 14  John GoodmanBilly CrystalSteve BuscemiJames Co...
# 15                                                NaN
# 16  ,Harriet Owen,Blayne Weaver,Corey Burton,Jeff ...
# 17  Jennifer HaleCorey BurtonRussi TaylorChristoph...
# 18                                                NaN
#
#                          Cinematography  \
# 0                                   NaN
# 1                        Dereck Joubert
# 2   ,David Hardberger,S. Douglas Smith,
# 3                         Tim Suhrstedt
# 4                     Peter Menzies Jr.
# 5                                   NaN
# 6                    Philippe Rousselot
# 7                         Adrian Biddle
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12               Karl Walter Lindenlaub
# 13                        Arthur Albert
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
#
#                                     Edited by  ... Narrated by Created by  \
# 0            ,Makoto Arai,Robert Fisher, Jr.,  ...   John Hurt        NaN
# 1                                 Nena Olwage  ...         NaN        NaN
# 2                             H. Lee Peterson  ...         NaN        NaN
# 3   ,Jessica Ambinder-Rojas,Lois Freeman-Fox,  ...         NaN        NaN
# 4                 ,Peter Honess,David Rennie,  ...         NaN        NaN
# 5                                         NaN  ...         NaN        NaN
# 6                             Michael Tronick  ...         NaN        NaN
# 7                              Gregory Perler  ...         NaN        NaN
# 8                 Pamela Ziegenhagen-Shefland  ...         NaN        NaN
# 9                              Tony Mizgalski  ...         NaN        NaN
# 10                             Susan Edmunson  ...         NaN        NaN
# 11                             Ellen Keneshea  ...         NaN        NaN
# 12                                Bruce Green  ...         NaN        NaN
# 13                    Tony LombardoPeck Prior  ...         NaN        NaN
# 14              Robert GrahamjonesJim Stewart  ...         NaN        NaN
# 15                                        NaN  ...         NaN        NaN
# 16                           Antonio F. Rocco  ...         NaN        NaN
# 17                              Julie Ann Lau  ...         NaN        NaN
# 18                                        NaN  ...         NaN        NaN
#
#    Genre Color process                                      Release dates  \
# 0    NaN           NaN                                  February 11, 2000
# 1    NaN           NaN                      ,March 10, 2000 (2000-03-10),
# 2    NaN           NaN        ,May 19, 2000 (2000-05-19) (United States),
# 3    NaN           NaN  ,December 17, 1999 (1999-12-17) (Premiere),,Ja...
# 4    NaN           NaN                        ,July 7, 2000 (2000-07-07),
# 5    NaN           NaN                  ,September 19, 2000 (2000-09-19),
# 6    NaN           NaN                  ,September 29, 2000 (2000-09-29),
# 7    NaN           NaN   ,November 22, 2000 (2000-11-22) (United States),
# 8    NaN           NaN  ,December 10, 2000 (2000-12-10) (premiere),Dec...
# 9    NaN           NaN  ,February 10, 2001 (2001-02-10) (premiere),,Fe...
# 10   NaN           NaN                   ,February 27, 2001 (2001-02-27),
# 11   NaN           NaN  ,June 3, 2001 (2001-06-03) (premiere),June 15,...
# 12   NaN           NaN  ,July 29, 2001 (2001-07-29) (El Capitan Theatr...
# 13   NaN           NaN                     ,October 5, 2001 (2001-10-05),
# 14   NaN           NaN  ,October 28, 2001 (2001-10-28) (El Capitan The...
# 15   NaN           NaN                                                NaN
# 16   NaN           NaN  ,February 10, 2002 (2002-02-10) (New York City...
# 17   NaN           NaN                   ,February 26, 2002 (2002-02-26),
# 18   NaN           NaN                                                NaN
#
#       Running time           Country Language  \
# 0    78 minutes[1]               NaN  English
# 1       72 minutes     United States  English
# 2    82 minutes[1]     United States  English
# 3       75 minutes     United States  English
# 4   104 minutes[2]     United States  English
# 5    75 minutes[1]               NaN  English
# 6      113 minutes     United States  English
# 7      100 minutes     United States  English
# 8       78 minutes     United States  English
# 9    83 minutes[1]     United States  English
# 10   69 minutes[2]  United States[2]  English
# 11   96 minutes[2]     United States  English
# 12  115 minutes[1]     United States  English
# 13      86 minutes     United States  English
# 14   92 minutes[1]     United States  English
# 15             NaN               NaN      NaN
# 16   73 minutes[1]  United States[1]  English
# 17      73 minutes     United States  English
# 18             NaN               NaN      NaN
#
#                                  Budget                            Box office
# 0   $15 million[4][5][6]–$30 million[7]                      $96.2 million[7]
# 1             $4,000,000 (estimated)[1]  $500,000 (USA) (30 November 2000)[1]
# 2                     $127.5 million[1]                     $349.8 million[1]
# 3                 $80–$85 million[1][2]                      $90.9 million[1]
# 4                        $65 million[3]                     $110.3 million[3]
# 5                                   NaN                                   NaN
# 6                        $30 million[1]                     $136.8 million[1]
# 7                        $85 million[1]                     $183.6 million[1]
# 8                          $100 million                        $169.6 million
# 9                        $23 million[2]                      $44.5 million[2]
# 10                                  NaN                                   NaN
# 11       $90–120 million[2][3][4][nb 1]                     $186.1 million[4]
# 12                          $26 million                     $165.3 million[2]
# 13                       $25 million[1]                      $18.6 million[1]
# 14                      $115 million[1]                     $577.4 million[1]
# 15                                  NaN                                   NaN
# 16                       $20 million[5]                     $115.1 million[5]
# 17                           $5 million                                   NaN
# 18                                  NaN                                   NaN
#
# [19 rows x 23 columns]

# %%
df.drop(df.index, inplace=True)

# %%
page = requests.get("https://en.m.wikipedia.org/wiki/Lilo_%26_Stitch")
page_content = bs(page.content)
#page = requests.get("https://en.m.wikipedia.org/wiki/Raya_and_the_Last_Dragon")
#page_content = bs(page.content)

# %%
page_content.table.get_text()
# Out:
# 'This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"Lilo & Stitch"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (August 2020) (Learn how and when to remove this template message)'
